# %% [markdown]
# # IMPORT

# %%
# import
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from binance.client import Client
from lib.backtest_data.backtest_data_manager import BacktestDataManager

# %% [markdown]
# # DATA ANALYSE

# %%
api_key = ""
api_secret = ""

# %%
mng = TestDataManager(api_key, api_secret)

# %%
csv_path = "input/03-01_03-08.csv"

mng.get_df_from_csv_source(csv_path)

# %%
mng.clean_dataset()

mng.df
# Out:
#                            SYMBOL  ENTER_PRICE  TAKE_PROFIT  STOP_LOSS  \
# TIME
# 2023-03-01 01:38:37.713361    TVK     0.051600     0.051703   0.051548
# 2023-03-03 15:31:05.685098    KEY     0.011760     0.012113   0.011642
# 2023-03-03 15:32:40.164762    KEY     0.011790     0.012144   0.011672
# 2023-03-03 15:32:45.941350    KEY     0.011796     0.012150   0.011678
# 2023-03-03 15:32:51.906874    KEY     0.011800     0.012154   0.011682
# ...                           ...          ...          ...        ...
# 2023-03-08 20:11:12.772725    REI     0.034500     0.035535   0.034155
# 2023-03-08 21:10:46.160433   LOKA     0.552100     0.568663   0.546579
# 2023-03-08 21:51:39.462702   TROY     0.004160     0.004285   0.004118
# 2023-03-08 21:57:50.735249   TROY     0.004380     0.004511   0.004336
# 2023-03-08 22:01:26.274043   TROY     0.004440     0.004573   0.004396
#
#                             RESULT  CANDLE_LENGTH  TP_RATIO  SL_RATIO  \
# TIME
# ...

# %%
mng.calculate_best_parameters(6, 8, 20, 31, 0, 11)
# Out:
# c:\Users\Theoc\Desktop\crypto_bot-1\DATA_ANALYSIS\lib\test_data\test_data_manager.py:86: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfResult = dfResult.append({'1H': bougie1h, '24H': bougie24h, 'SL': SLRatio, 'TP': TPRatio, 'USDT': usdt, 'OK': ok, 'NOK': nok}, ignore_index=True)
# c:\Users\Theoc\Desktop\crypto_bot-1\DATA_ANALYSIS\lib\test_data\test_data_manager.py:86: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfResult = dfResult.append({'1H': bougie1h, '24H': bougie24h, 'SL': SLRatio, 'TP': TPRatio, 'USDT': usdt, 'OK': ok, 'NOK': nok}, ignore_index=True)
# c:\Users\Theoc\Desktop\crypto_bot-1\DATA_ANALYSIS\lib\test_data\test_data_manager.py:86: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
mng.calculate_wallet_state(1000, 0.03, 0.01, 2, 8)
# Out:
# c:\Users\Theoc\Desktop\crypto_bot-1\DATA_ANALYSIS\lib\test_data\test_data_manager.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tt["wallet_state"][index] = usdt
# c:\Users\Theoc\Desktop\crypto_bot-1\DATA_ANALYSIS\lib\test_data\test_data_manager.py:152: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tt["actual_draw_back"][index] = drawback
# c:\Users\Theoc\Desktop\crypto_bot-1\DATA_ANALYSIS\lib\test_data\test_data_manager.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
mng.df = mng.df[:1]

# %%
mng.df
# Out:
#                            SYMBOL  ENTER_PRICE  TAKE_PROFIT  STOP_LOSS  \
# TIME
# 2023-03-01 01:38:37.713361    TVK     0.051600     0.051703   0.051548
# 2023-03-03 15:31:05.685098    KEY     0.011760     0.012113   0.011642
# 2023-03-03 15:32:40.164762    KEY     0.011790     0.012144   0.011672
# 2023-03-03 15:32:45.941350    KEY     0.011796     0.012150   0.011678
# 2023-03-03 15:32:51.906874    KEY     0.011800     0.012154   0.011682
# ...                           ...          ...          ...        ...
# 2023-03-08 20:11:12.772725    REI     0.034500     0.035535   0.034155
# 2023-03-08 21:10:46.160433   LOKA     0.552100     0.568663   0.546579
# 2023-03-08 21:51:39.462702   TROY     0.004160     0.004285   0.004118
# 2023-03-08 21:57:50.735249   TROY     0.004380     0.004511   0.004336
# 2023-03-08 22:01:26.274043   TROY     0.004440     0.004573   0.004396
#
#                             RESULT  CANDLE_LENGTH  TP_RATIO  SL_RATIO  \
# TIME
# ...

# %%
mng.plot_wallet_state()
